# %%
import pandas as pd

v3gradesExample = 'v3grades.json'
df = pd.read_json(v3gradesExample)
df
# Out:
#         average campus  course                             course_title  \
# 0     89.000000   UBCV     390     Asian Migrations in a Global Context
# 1     89.000000   UBCV     390     Asian Migrations in a Global Context
# 2     81.700000   UBCV     327                          Teaching Adults
# 3     78.200000   UBCV     327                          Teaching Adults
# 4     82.500000   UBCV     327                          Teaching Adults
# ...         ...    ...     ...                                      ...
# 1718  75.500000   UBCV     150  Writing and Research in the Disciplines
# 1719  79.400000   UBCV     150  Writing and Research in the Disciplines
# 1720  78.400000   UBCV     150  Writing and Research in the Disciplines
# 1721  74.400000   UBCV     150  Writing and Research in the Disciplines
# 1722  76.245719   UBCV     150  Writing and Research in the Disciplines
#
#      detail      educators         faculty_title  \
# 0         A       Henry Yu       Faculty of Arts
# ...

# %%
import json
with open(v3gradesExample, "r") as file:
    fileData  = file.read()
    jsonData = json.loads(fileData)

print(type(fileData))
print(type(jsonData))
result = pd.json_normalize(jsonData)
# result = pd.DataFrame.from_records(x)
result
# Out:
# <class 'str'>
# <class 'list'>
#         average campus course                             course_title detail  \
# 0     89.000000   UBCV    390     Asian Migrations in a Global Context      A
# 1     89.000000   UBCV    390     Asian Migrations in a Global Context      A
# 2     81.700000   UBCV    327                          Teaching Adults
# 3     78.200000   UBCV    327                          Teaching Adults
# 4     82.500000   UBCV    327                          Teaching Adults
# ...         ...    ...    ...                                      ...    ...
# 1718  75.500000   UBCV    150  Writing and Research in the Disciplines      B
# 1719  79.400000   UBCV    150  Writing and Research in the Disciplines      B
# 1720  78.400000   UBCV    150  Writing and Research in the Disciplines      B
# 1721  74.400000   UBCV    150  Writing and Research in the Disciplines      B
# 1722  76.245719   UBCV    150  Writing and Research in the Disciplines      B
#
# ...

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
# import pandas as pd

# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')

app = Dash(__name__)

app.layout = html.Div([
    html.H1(children='Title of Dash App', style={'textAlign':'center'}),
    dcc.Dropdown(df.faculty_title.unique(), 'Faculty of Arts', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
])

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    dff = df[df.faculty_title==value]
    return px.line(dff, x='course', y='average')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
